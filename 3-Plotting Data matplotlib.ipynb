# %%
# %load_ext watermark
# %watermark
# Out:
# 2020-11-08T12:38:41+01:00
#
# CPython 3.7.1
# IPython 7.18.1
#
# compiler   : MSC v.1915 64 bit (AMD64)
# system     : Windows
# release    : 10
# machine    : AMD64
# processor  : AMD64 Family 23 Model 17 Stepping 0, AuthenticAMD
# CPU cores  : 8
# interpreter: 64bit

# %% [markdown]
# ### Cargar las librerias

# %%
# From matplotlib, import pyplot under the alias plt
from matplotlib import pyplot as plt
import pandas as pd

# %%
# para abrir debemos de tener cuidado el tipo de separacion 
# abrimos y vemos si se ha cargado correctamente
deshaun = pd.read_csv('deshaun.csv',sep = ';')
deshaun.head()
# Out:
#    Unnamed: 0 day_of_week  hours_worked
# 0           0           M             8
# 1           1          Tu             5
# 2           2           W             3
# 3           3          Th             5
# 4           4           F             8

# %%
# Plot Officer Deshaun's hours_worked vs. day_of_week
plt.plot(deshaun.day_of_week, deshaun.hours_worked)

# Display Deshaun's plot
plt.show()

# %%
# abrimos y vemos si se ha cargado correctamente
# teener cuidado con el nombre del objeto
aditya = pd.read_csv('aditya.csv',sep = ';')
deshaun.head()
# Out:
#    Unnamed: 0 day_of_week  hours_worked
# 0           0           M             8
# 1           1          Tu             5
# 2           2           W             3
# 3           3          Th             5
# 4           4           F             8

# %%
# abrimos y vemos si se ha cargado correctamente
mengfei = pd.read_csv('mengfei.csv',sep = ';')
deshaun.head()
# Out:
#    Unnamed: 0 day_of_week  hours_worked
# 0           0           M             8
# 1           1          Tu             5
# 2           2           W             3
# 3           3          Th             5
# 4           4           F             8

# %%
#Plot Officer Deshaun's hours_worked vs. day_of_week
plt.plot(deshaun.day_of_week, deshaun.hours_worked)

# Plot Officer Aditya's hours_worked vs. day_of_week
plt.plot(aditya.day_of_week, aditya.hours_worked)

# Plot Officer Mengfei's hours_worked vs. day_of_week
plt.plot(mengfei.day_of_week,mengfei.hours_worked)

# Display all three line plots
plt.show()

# %% [markdown]
# ### Adding a legend

# %%
# Add a label to Deshaun's plot
plt.plot(deshaun.day_of_week, deshaun.hours_worked, label="Deshaun")

# Officer Aditya
plt.plot(aditya.day_of_week, aditya.hours_worked)

# Officer Mengfei
plt.plot(mengfei.day_of_week, mengfei.hours_worked)

# Display plot
plt.show()

# %%
# Officer Deshaun
plt.plot(deshaun.day_of_week, deshaun.hours_worked, label='Deshaun')

# Add a label to Aditya's plot
plt.plot(aditya.day_of_week, aditya.hours_worked, label= "Aditya")

# Add a label to Mengfei's plot
plt.plot(mengfei.day_of_week, mengfei.hours_worked, label="Mengfei")

# Display plot
plt.show()

# %%
# Lines
plt.plot(deshaun.day_of_week, deshaun.hours_worked, label='Deshaun')
plt.plot(aditya.day_of_week, aditya.hours_worked, label='Aditya')
plt.plot(mengfei.day_of_week, mengfei.hours_worked, label='Mengfei')

# Add a title
plt.title("Días de la semana trabajados")

# Add y-axis label
plt.ylabel("Días de la semana")

# Legend
plt.legend()
# Display plot
plt.show()

# %%
# abrimos y vemos si se ha cargado correctamente
six_months = pd.read_csv('six_months.csv',sep = ';')
six_months.head()
# Out:
#    Unnamed: 0 month  hours_worked
# 0           0   Jan           160
# 1           1   Feb           185
# 2           2   Mar           182
# 3           3   Apr           195
# 4           4   Jun            50

# %%
# Create plot
plt.plot(six_months.month, six_months.hours_worked)

# Add annotation "Missing June data" at (2.5, 80)
plt.text(2.5, 80,"Missing June data")

# Display graph
plt.show()
